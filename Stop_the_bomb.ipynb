# %%
from multiprocessing import Process
import random
import time 

# input time in seconds 
t = 60
#LLAMANDO FUNCION 1

def compare(b):
        try:
            a=round(float(input()))
        except ValueError:
            print('This is not a number! Try again!')
            return compare(b)
        else:
            print('The entry is',a)
            if a==b:
                print(a,"You're right! Continue!")
                return 1
            else:
                print(a,"You're wrong!!! Try again!")
                return 0

# define the countdown func. 
def countdown(t): 
    
    while t: 
        mins, secs = divmod(t, 60) 
        timer = '{:02d}:{:02d}'.format(mins, secs) 
        print(timer, end="\r") 
        time.sleep(1) 
        t -= 1
      
    print('BOOOOM!!') 
    rounds=0
    n_rounds=5
    cpu = random.sample(range(0, 10), 4)
    #print(cpu)
    contador=0
        
    for b in cpu:
        contador +=compare(b)
    if contador == 4:
        print('You deactivate the bomb!')
        print("The combination is: ",cpu)
        
    print(rounds,"chance. Try again!")
    if rounds == n_rounds:
        print("BOOOOOM "*20)
  

#LLAMANDO FUNCION 2

def guess ():
    def compare(b):
        try:
            a=round(float(input()))
        except ValueError:
            print('This is not a number! Try again!')
            return compare(b)
        else:
            print('The entry is',a)
            if a==b:
                print(a,"You're right! Continue!")
                return 1
            else:
                print(a,"You're wrong!!! Try again!")
                return 0
    rounds=0
    n_rounds=5
    cpu = random.sample(range(0, 10), 4)
    #print(cpu)
    contador=0
        
    for b in cpu:
        contador +=compare(b)
    if contador == 4:
        print('You deactivate the bomb!')
        print("The combination is: ",cpu)
        
    print(rounds,"chance. Try again!")
    if rounds == n_rounds:
        print("BOOOOOM "*20)

if __name__ == '__main__':
    p1 = Process(target=countdown(t))
    p1.start()
    p2 = Process(target=guess())
    p2.start()
    p1.join()
    p2.join()
# Out:
# BOOOOM!!
# 1
# The entry is 1
# 1 You're wrong!!! Try again!
# 2
# The entry is 2
# 2 You're wrong!!! Try again!
# 3
# The entry is 3
# 3 You're wrong!!! Try again!
# 4
# The entry is 4
# 4 You're wrong!!! Try again!
# 0 chance. Try again!
# 5
# The entry is 5
# 5 You're wrong!!! Try again!
# 6
# The entry is 6
# 6 You're wrong!!! Try again!
# 7
# The entry is 7
# 7 You're wrong!!! Try again!
# 8
# The entry is 8
# 8 You're wrong!!! Try again!
# 0 chance. Try again!

# %%
import random
import time 

# input time in seconds 
t = 60
#LLAMANDO FUNCION 1

def compare(b):
        try:
            a=round(float(input()))
        except ValueError:
            print('This is not a number! Try again!')
            return compare(b)
        else:
            print('The entry is',a)
            if a==b:
                print(a,"You're right! Continue!")
                return 1
            else:
                print(a,"You're wrong!!! Try again!")
                return 0

# define the countdown func. 
def countdown(t): 
    
    while t: 
        mins, secs = divmod(t, 60) 
        timer = '{:02d}:{:02d}'.format(mins, secs) 
        print(timer, end="\r") 
        time.sleep(1) 
        t -= 1
      
        print('BOOOOM!!') 
        rounds=0
        n_rounds=5
        cpu = random.sample(range(0, 10), 4)
    #print(cpu)
        contador=0
        
        for b in cpu:
            contador +=compare(b)
        if contador == 4:
            print('You deactivate the bomb!')
            print("The combination is: ",cpu)
        
        print(rounds,"chance. Try again!")
        if rounds == n_rounds:
            print("BOOOOOM "*20)
countdown(t)
# Out:
# BOOOOM!!

# %%
#Importamos la random

import random

#CPU elige una combinación
rounds=0
n_rounds=4
cpu = random.sample(range(0, 10), 4)
print(cpu)

#Creamos una función para comparar
def compare(b):
        try:
            a=round(float(input()))
            while a>9:
                a=round(float(input("Try a number between 0 and 9: ")))
            while a<0:
                a=round(float(input("Try a number between 0 and 9: ")))
        except ValueError:
            print('This is not a number! Try again!')
            return compare(b)
        else:
            print('The entry is',a)
            if a==b:
                print(a,"You're right! Continue!")
                return 1
            else:
                print(a,"You're wrong!!! Try again!")
                return 0

# %%
print("Thousands of residents were forced to evacuate a Frankfurt district today, \n where it was found an explosive device, one of thousands dropped over Germany by the \n Royal Air Force during the final years of World War II.  \n  \n \n Unfortunately, field agents rarely know how to defuse the bomb, \n so they will contact you, a bomb disposal expert.\n \n \n You only have 4 chances to find the right combination to deactivate the bomb!\n")
print("Use this manual as a guide to defuse the bomb. \n 1. Numbers shall be integer numbers from 0 to 9. \n 2. If you use flotants, the system will round it up. \n 3. You cannot use letters or symbols.\n")

#Agregamos un loop hasta cumplir la condición
while rounds <n_rounds:
    
    rounds +=1
    contador=0
        
    for b in cpu:
        contador +=compare(b)
    if contador == 4:
        print('You deactivate the bomb!')
        print("The combination is: ",cpu)
        print("Mission accomplished!")
        break
    print("Chance",rounds,"Try again!")
    if rounds == n_rounds:
        print("\n")
        print("B"+"OOOOO"*200+"M")
        print("\n")
        print("The combination was: ",cpu)

# %% [markdown]
# ####
